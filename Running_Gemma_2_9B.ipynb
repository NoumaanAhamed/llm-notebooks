# %% [markdown]
# <a href="https://colab.research.google.com/github/NoumaanAhamed/llm-notebooks/blob/main/Running_Gemma_2_9B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Create A HuggingFace Account
#
# Gemma 2 is a Gated Model that comes with the [same license](https://ai.google.dev/gemma/terms) as the first iteration, which is a permissive license that allows redistribution, fine-tuning, commercial use, and derivative works.
#
# Go to [Gemma-2-9b](https://huggingface.co/google/gemma-2-9b-it) and Accept the Terms and Conditions for the Gated Model.
#
# Grab a token for the next step from [Here](https://huggingface.co/settings/tokens)

# %% [markdown]
# ## Login to HuggingFace with Token

# %%
# !huggingface-cli login
# Run the Above code and Paste your HuggingFace Token from https://huggingface.co/settings/tokens

# %% [markdown]
# ## Setup Inference Environment

# %%
# !pip install -q git+https://github.com/huggingface/transformers.git accelerate
# Transformers -> Library from Huggingface for accessing models
# Accelerate -> Faster and efficient loading and inferencing of models
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 59.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Import Required Packages

# %%
from transformers import pipeline
import torch

# %% [markdown]
# ## Initialise the Text Generation pipeline
#
# P.S. Make sure to accept the terms and conditions from the model page [here](https://huggingface.co/google/gemma-2-9b-it)

# %%
model_id = "google/gemma-2-9b-it"

pipe = pipeline(
    "text-generation",
    model=model_id,
    model_kwargs={"torch_dtype": torch.bfloat16},
    device_map="auto",
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/857 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/39.1k [00:00<?, ?B/s]
# ...
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/3.67G [00:00<?, ?B/s]
# ...

# %% [markdown]
# ## Define the Messages

# %%
messages = [
    {"role": "user", "content": "Who are you?"},
]

# %% [markdown]
# ## Pass the outputs to the pipeline

# %%
outputs = pipe(
    messages,
    max_new_tokens=256,
)

# %% [markdown]
# ## Generate response

# %%
response = outputs[0]["generated_text"][-1]["content"]
print(response)
# Out:
# I am Gemma, an open-weights AI assistant. I am a large language model trained by Google DeepMind. My purpose is to help users by understanding and responding to their requests in a helpful, informative, and comprehensive way.
#
# Here are some key things to know about me:
#
# * **Open-weights:** My weights are publicly available, meaning anyone can access and study them.
# * **Text-only:** I can only communicate through text. I cannot generate images, sound, or videos.
# * **Limited knowledge:** My knowledge is based on the data I was trained on, which has a cutoff point. I do not have access to real-time information or the ability to search the internet.
# * **Created by the Gemma team:** I was developed by a team of engineers and researchers at Google DeepMind.
#
# I am still under development, but I am learning new things every day. I am excited to see how people use me to explore new ideas and accomplish their goals.
